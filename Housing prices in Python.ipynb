# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("housing.csv")

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X= data.drop(['median_house_value'], axis= 1)
y= data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=2)

# %%
train_data= X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 767      -122.09     37.65                27.0       2630.0           722.0
# 13691    -117.24     34.13                24.0       1203.0           310.0
# 8414     -118.35     33.94                42.0       1028.0           278.0
# 2715     -115.58     32.81                10.0       1088.0           203.0
# 17885    -121.97     37.40                17.0       2937.0           558.0
# ...          ...       ...                 ...          ...             ...
# 11195    -117.93     33.83                30.0       1561.0           381.0
# 5092     -118.28     33.97                35.0       2305.0           634.0
# 13239    -117.66     34.13                17.0       3229.0           405.0
# 11724    -120.04     39.24                30.0       2369.0           469.0
# 15424    -117.27     33.20                34.0       1852.0           322.0
#
#        population  households  median_income ocean_proximity  \
# 767        1414.0       634.0         2.8203        NEAR BAY
# 13691       594.0       187.0         1.1522          INLAND
# 8414       1369.0       261.0         3.3125       <1H OCEAN
# 2715        533.0       201.0         3.6597          INLAND
# 17885      1662.0       533.0         5.8792       <1H OCEAN
# ...           ...         ...            ...             ...
# 11195      1104.0       391.0         3.3750       <1H OCEAN
# 5092       1978.0       568.0         1.3750       <1H OCEAN
# 13239      1289.0       407.0         6.3842          INLAND
# 11724       510.0       213.0         2.6500          INLAND
# 15424       978.0       332.0         4.3542       <1H OCEAN
#
#        median_house_value
# 767              195200.0
# 13691             87500.0
# 8414             144600.0
# 2715              87500.0
# 17885            255500.0
# ...                   ...
# 11195            201900.0
# 5092             100000.0
# 13239            307100.0
# 11724            123800.0
# 15424            156900.0
#
# [20431 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_404\1402113604.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_data.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924651           -0.109409     0.045465
# latitude            -0.924651  1.000000            0.011980    -0.036635
# housing_median_age  -0.109409  0.011980            1.000000    -0.360682
# total_rooms          0.045465 -0.036635           -0.360682     1.000000
# total_bedrooms       0.069579 -0.066947           -0.320512     0.930380
# population           0.100270 -0.108952           -0.295856     0.857282
# households           0.056495 -0.071720           -0.302847     0.918993
# median_income       -0.015465 -0.079717           -0.118196     0.197935
# median_house_value  -0.045327 -0.144686            0.106489     0.133319
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069579    0.100270    0.056495      -0.015465
# latitude                 -0.066947   -0.108952   -0.071720      -0.079717
# housing_median_age       -0.320512   -0.295856   -0.302847      -0.118196
# total_rooms               0.930380    0.857282    0.918993       0.197935
# total_bedrooms            1.000000    0.877753    0.979733      -0.007668
# population                0.877753    1.000000    0.907184       0.005127
# households                0.979733    0.907184    1.000000       0.013494
# median_income            -0.007668    0.005127    0.013494       1.000000
# median_house_value        0.049724   -0.025295    0.064921       0.688336
#
#                     median_house_value
# longitude                    -0.045327
# latitude                     -0.144686
# housing_median_age            0.106489
# total_rooms                   0.133319
# total_bedrooms                0.049724
# population                   -0.025295
# households                    0.064921
# median_income                 0.688336
# median_house_value            1.000000

# %%
sns.heatmap(train_data.corr())    ## annot means annotation
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_404\3098456701.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr())    ## annot means annotation
# <Axes: >

# %%
sns.heatmap(train_data.corr(), annot= True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_404\528470088.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(), annot= True)
# <Axes: >

# %%
sns.heatmap(train_data.corr(), annot= True, cmap="YlGnBu")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_404\3445711248.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(), annot= True, cmap="YlGnBu")
# <Axes: >

# %%
plt.figure(figsize=(20,10))
sns.heatmap(train_data.corr(), annot= True, cmap="YlGnBu")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_404\3599253807.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(), annot= True, cmap="YlGnBu")
# <Axes: >

# %%
train_data['total_rooms']= np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']= np.log(train_data['total_bedrooms']+1)
train_data['population']= np.log(train_data['population']+1)
train_data['households']= np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9033
# INLAND        6495
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 767            0       0       0         1           0
# 13691          0       1       0         0           0
# 8414           1       0       0         0           0
# 2715           0       1       0         0           0
# 17885          1       0       0         0           0
# ...          ...     ...     ...       ...         ...
# 11195          1       0       0         0           0
# 5092           1       0       0         0           0
# 13239          0       1       0         0           0
# 11724          0       1       0         0           0
# 15424          1       0       0         0           0
#
# [20431 rows x 5 columns]

# %%
train_data.join(pd.get_dummies(train_data.ocean_proximity))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 767      -122.09     37.65                27.0     7.875119        6.583409
# 13691    -117.24     34.13                24.0     7.093405        5.739793
# 8414     -118.35     33.94                42.0     6.936343        5.631212
# 2715     -115.58     32.81                10.0     6.993015        5.318120
# 17885    -121.97     37.40                17.0     7.985484        6.326149
# ...          ...       ...                 ...          ...             ...
# 11195    -117.93     33.83                30.0     7.353722        5.945421
# 5092     -118.28     33.97                35.0     7.743270        6.453625
# 13239    -117.66     34.13                17.0     8.080237        6.006353
# 11724    -120.04     39.24                30.0     7.770645        6.152733
# 15424    -117.27     33.20                34.0     7.524561        5.777652
#
#        population  households  median_income ocean_proximity  \
# 767      7.254885    6.453625         2.8203        NEAR BAY
# 13691    6.388561    5.236442         1.1522          INLAND
# 8414     7.222566    5.568345         3.3125       <1H OCEAN
# 2715     6.280396    5.308268         3.6597          INLAND
# 17885    7.416378    6.280396         5.8792       <1H OCEAN
# ...           ...         ...            ...             ...
# 11195    7.007601    5.971262         3.3750       <1H OCEAN
# 5092     7.590347    6.343880         1.3750       <1H OCEAN
# 13239    7.162397    6.011267         6.3842          INLAND
# 11724    6.236370    5.365976         2.6500          INLAND
# 15424    6.886532    5.808142         4.3542       <1H OCEAN
#
#        median_house_value  <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 767              195200.0          0       0       0         1           0
# 13691             87500.0          0       1       0         0           0
# 8414             144600.0          1       0       0         0           0
# 2715              87500.0          0       1       0         0           0
# 17885            255500.0          1       0       0         0           0
# ...                   ...        ...     ...     ...       ...         ...
# 11195            201900.0          1       0       0         0           0
# 5092             100000.0          1       0       0         0           0
# 13239            307100.0          0       1       0         0           0
# 11724            123800.0          0       1       0         0           0
# 15424            156900.0          1       0       0         0           0
#
# [20431 rows x 15 columns]

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 767      -122.09     37.65                27.0     7.875119        6.583409
# 13691    -117.24     34.13                24.0     7.093405        5.739793
# 8414     -118.35     33.94                42.0     6.936343        5.631212
# 2715     -115.58     32.81                10.0     6.993015        5.318120
# 17885    -121.97     37.40                17.0     7.985484        6.326149
# ...          ...       ...                 ...          ...             ...
# 11195    -117.93     33.83                30.0     7.353722        5.945421
# 5092     -118.28     33.97                35.0     7.743270        6.453625
# 13239    -117.66     34.13                17.0     8.080237        6.006353
# 11724    -120.04     39.24                30.0     7.770645        6.152733
# 15424    -117.27     33.20                34.0     7.524561        5.777652
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 767      7.254885    6.453625         2.8203            195200.0          0
# 13691    6.388561    5.236442         1.1522             87500.0          0
# 8414     7.222566    5.568345         3.3125            144600.0          1
# 2715     6.280396    5.308268         3.6597             87500.0          0
# 17885    7.416378    6.280396         5.8792            255500.0          1
# ...           ...         ...            ...                 ...        ...
# 11195    7.007601    5.971262         3.3750            201900.0          1
# 5092     7.590347    6.343880         1.3750            100000.0          1
# 13239    7.162397    6.011267         6.3842            307100.0          0
# 11724    6.236370    5.365976         2.6500            123800.0          0
# 15424    6.886532    5.808142         4.3542            156900.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 767         0       0         1           0
# 13691       1       0         0           0
# 8414        0       0         0           0
# 2715        1       0         0           0
# 17885       0       0         0           0
# ...       ...     ...       ...         ...
# 11195       0       0         0           0
# 5092        0       0         0           0
# 13239       1       0         0           0
# 11724       1       0         0           0
# 15424       0       0         0           0
#
# [20431 rows x 14 columns]

# %%
plt.figure(figsize=(15,6))
sns.heatmap(train_data.corr(), annot= True, cmap= 'YlGnBu')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x='latitude', y='longitude', data=train_data)
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x='latitude', y='longitude', data=train_data, hue= 'median_house_value')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
plt.figure(figsize=(15,13))
sns.scatterplot(x='latitude', y='longitude', data=train_data, hue= 'median_house_value', palette= 'coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio']= train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_rooms']= train_data['total_rooms']/ train_data['households']

# %%
from sklearn.linear_model import LinearRegression

X_train, y_train= train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']

reg= LinearRegression()

reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_data= x_test.join(y_test)

test_data['total_rooms']= np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']= np.log(test_data['total_bedrooms']+1)
test_data['population']= np.log(test_data['population']+1)
test_data['households']= np.log(test_data['households']+1)

test_data=train_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ratio']= test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms']= test_data['total_rooms']/ test_data['households']
